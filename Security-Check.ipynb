# %% [markdown]
# # A few Security tools

# %% [markdown]
# # If save and checkpoint fails change permissions in terminal
# sudo chmod 777 -R .ipynb_checkpoints<br />
# sudo chown jack:jack -R .ipynb_checkpoints<br />

# %%
# Current directory
# !pwd
# Out:
# /home/jack/Desktop/LBRY-toolbox

# %% [markdown]
# ## Search for a word in a directory

# %%
import os

user_input = input('What is the name of your directory ? :')
directory = os.listdir(user_input)

searchstring = input('What word are you trying to find ? :')

for fname in directory:
    if os.path.isfile(user_input + os.sep + fname):
        # Full path
        f = open(user_input + os.sep + fname, 'r',encoding='latin1')

        if searchstring in f.read():
            print('found string in file: %s' % fname)
        else:
            print('.', end=" ")
        f.close()
# Out:
# What is the name of your directory ? :/home/jack/Desktop/LBRY-toolbox
# What word are you trying to find ? :private
# . . . . found string in file: stream_list2.db
# . . . . . . . . . found string in file: Untitled1.ipynb
# . found string in file: stream_list-exp.db
# . . . found string in file: How-to-get-claim_list-all-working.ipynb
# . . . . . found string in file: claim_list.json
# found string in file: stream_list-exp.json
# . found string in file: How-to-get-stream_list-all-working.ipynb
# . . . . . . found string in file: 5279.db
# . . . . . . . . . . . . found string in file: LBRYDATA.db
# . found string in file: claim_list.db
# . . found string in file: stream_list.db
# . . . . . . . . found string in file: LBRY-Python-Place-Data-in-Database.ipynb
# .

# %% [markdown]
# ## Checking I am not publishing any private keys or seeds to to GitHub

# %%
# !grep -Ril '"private_key"' ./

# %%
import sqlite3
conn = sqlite3.connect("stream_list2.db")
c = conn.cursor()
# Search database for words private_key and seed 
for row in c.execute("SELECT ROWID,* from LBRY"):
    if '"private_key"' in row[1] or '"seed"' in row[1]:
        print (row[0],": ",row[1])

# %%
import sqlite3
conn = sqlite3.connect("stream_list2.db")
c = conn.cursor()
SEARCH = input("SEARCH: ")
for row in c.execute("SELECT ROWID,* from LBRY"):
    if SEARCH in row[1]:
        print (row[0],": ",row[1])
# Out:
# SEARCH: private
# 65 :  {
#   "jsonrpc": "2.0",
#   "result": {
#     "total_items": 1135,
#     "items": [
#       {
#         "permanent_url": "lbry://life-is-good-i-am-not-twenty-four#51d3576a57304a0f68f3db8576aafdce8a4a9aaa",
#         "type": "claim",
#         "is_mine": true,
#         "is_channel_signature_valid": true,
#         "timestamp": 1574820709,
#         "value": {
# ...
