# %% [markdown]
# # Create a file to monitor your wallet balance
# ## Then using that data to create plot.
# The `wallet` executable created will append data in a json format to file > wallet.balance

# %% [markdown]
# ## Creating the bash `wallet` executable:
# This file will build the data resource > wallet.balance  <br /> <br />
# Do not forget to make this file executable: chmod +x wallet <br />
# If you cp or sym-link wallet to `/usr/bin` it can be used in a cron job <br />
# ( on my computer a file in `/usr/local/bin` will not be executed in a cron job )

# %%
# %%writefile wallet
# #!/bin/bash
# # do not forget to make this file executable: chmod +x wallet
# # if you cp or symlink wallet to /usr/bin it can be used in a cron job
# #echo curly brackets and the date into the datafile > wallet.balance
# echo "{ \"Date\": `date +%s`," >>/home/jack/wallet.balance
# # sent the results of the command: lbrynet wallet balance into the file > wallet.balance
# lbrynet wallet balance >>/home/jack/wallet.balance
# # echo and ending curly-brackets to  > wallet.balance
# echo "}" >>/home/jack/wallet.balance
# # Then look at > wallet.balance
# cat /home/jack/wallet.balance

# %% [markdown]
# The results of the above file being executed will append the wallet.balance in the following format: <br /> <br />
# `{ "Date": 1579732895,
# {
#   "available": "0.1950495",
#   "reserved": "14335.468",
#   "reserved_subtotals": {
#     "claims": "910.158",
#     "supports": "6211.0",
#     "tips": "7214.31"
#   },
#   "total": "14335.6630495"
# }
# }`

# %% [markdown]
# ## The result of the `wallet` being executed

# %%
# The result of the `wallet` being executed 
# Each time it is run it will append the wallet.balance file
# This may be set up torun as a cron job
# !wallet
# Out:
# {
#   "available": "703.7053835",
#   "reserved": "9564.503",
#   "reserved_subtotals": {
#     "claims": "457.503",
#     "supports": "4318.0",
#     "tips": "4789.0"
#   },
#   "total": "10268.2083835"
# }
# {
#   "available": "703.7053835",
#   "reserved": "9616.503",
#   "reserved_subtotals": {
#     "claims": "457.503",
#     "supports": "4318.0",
#     "tips": "4841.0"
#   },
#   "total": "10320.2083835"
# }
# {
#   "available": "704.7053835",
#   "reserved": "9616.503",
#   "reserved_subtotals": {
#     "claims": "457.503",
#     "supports": "4318.0",
#     "tips": "4841.0"
#   },
#   "total": "10321.2083835"
# }
# {
#   "available": "704.7053835",
#   "reserved": "9618.503",
#   "reserved_subtotals": {
#     "claims": "457.503",
#     "supports": "4318.0",
#     "tips": "4843.0"
#   },
#   "total": "10323.2083835"
# }
# {
#   "available": "724.7053835",
#   "reserved": "9618.503",
#   "reserved_subtotals": {
#     "claims": "457.503",
#     "supports": "4318.0",
#     "tips": "4843.0"
#   },
#   "total": "10343.2083835"
# }
# {
#   "available": "723.7052425",
#   "reserved": "9782.503",
#   "reserved_subtotals": {
#     "claims": "457.503",
#     "supports": "4318.0",
#     "tips": "5007.0"
#   },
#   "total": "10506.2082425"
# }
# {
#   "available": "723.7052425",
#   "reserved": "9827.503",
#   "reserved_subtotals": {
#     "claims": "457.503",
#     "supports": "4318.0",
#     "tips": "5052.0"
#   },
#   "total": "10551.2082425"
# }
# {
#   "available": "660.3136765",
#   "reserved": "9913.803",
#   "reserved_subtotals": {
#     "claims": "524.803",
#     "supports": "4318.0",
#     "tips": "5071.0"
#   },
#   "total": "10574.1166765"
# }
# {
#   "available": "650.135424",
#   "reserved": "10002.953",
#   "reserved_subtotals": {
#     "claims": "524.953",
#     "supports": "4318.0",
#     "tips": "5160.0"
#   },
#   "total": "10653.088424"
# }
# {
#   "available": "746.135424",
#   "reserved": "10978.953",
#   "reserved_subtotals": {
#     "claims": "524.953",
#     "supports": "4318.0",
#     "tips": "6136.0"
#   },
#   "total": "11725.088424"
# }
# {
#   "available": "446.133797",
#   "reserved": "11278.953",
#   "reserved_subtotals": {
#     "claims": "524.953",
#     "supports": "4618.0",
#     "tips": "6136.0"
#   },
#   "total": "11725.086797"
# }
# {
#   "available": "636.0170835",
#   "reserved": "11360.953",
#   "reserved_subtotals": {
#     "claims": "534.953",
#     "supports": "4618.0",
#     "tips": "6208.0"
#   },
#   "total": "11996.9700835"
# }
# {
#   "available": "528.02055",
#   "reserved": "11534.948",
#   "reserved_subtotals": {
#     "claims": "634.948",
#     "supports": "4618.0",
#     "tips": "6282.0"
#   },
#   "total": "12062.96855"
# }
# {
#   "available": "528.02055",
#   "reserved": "11566.948",
#   "reserved_subtotals": {
#     "claims": "634.948",
#     "supports": "4618.0",
#     "tips": "6314.0"
#   },
#   "total": "12094.96855"
# }
# {
#   "available": "528.02055",
#   "reserved": "11629.048",
#   "reserved_subtotals": {
#     "claims": "634.948",
#     "supports": "4618.0",
#     "tips": "6376.1"
#   },
#   "total": "12157.06855"
# }
# {
#   "available": "438.020394",
#   "reserved": "11835.058",
#   "reserved_subtotals": {
#     "claims": "634.958",
#     "supports": "4618.0",
#     "tips": "6582.1"
#   },
#   "total": "12273.078394"
# }
# {
#   "available": "428.0202515",
#   "reserved": "11892.058",
#   "reserved_subtotals": {
#     "claims": "634.958",
#     "supports": "4618.0",
#     "tips": "6639.1"
#   },
#   "total": "12320.0782515"
# }
# {
#   "available": "428.0202515",
#   "reserved": "11910.058",
#   "reserved_subtotals": {
#     "claims": "634.958",
#     "supports": "4618.0",
#     "tips": "6657.1"
#   },
#   "total": "12338.0782515"
# }
# { "Date": 1578967168,
# {
#   "available": "428.0202515",
#   "reserved": "11910.058",
#   "reserved_subtotals": {
#     "claims": "634.958",
#     "supports": "4618.0",
#     "tips": "6657.1"
#   },
#   "total": "12338.0782515"
# }
# }
# { "Date": 1579001785,
# {
#   "available": "380.028745",
#   "reserved": "11966.048",
#   "reserved_subtotals": {
#     "claims": "684.948",
#     "supports": "4618.0",
#     "tips": "6663.1"
#   },
#   "total": "12346.076745"
# }
# }
# { "Date": 1579003168,
# {
#   "available": "380.028745",
#   "reserved": "11966.048",
#   "reserved_subtotals": {
#     "claims": "684.948",
#     "supports": "4618.0",
#     "tips": "6663.1"
#   },
#   "total": "12346.076745"
# }
# }
# { "Date": 1579041407,
# {
#   "available": "380.028745",
#   "reserved": "11981.048",
#   "reserved_subtotals": {
#     "claims": "684.948",
#     "supports": "4618.0",
#     "tips": "6678.1"
#   },
#   "total": "12361.076745"
# }
# }
# { "Date": 1579082336,
# {
#   "available": "401.028745",
#   "reserved": "11995.048",
#   "reserved_subtotals": {
#     "claims": "684.948",
#     "supports": "4618.0",
#     "tips": "6692.1"
#   },
#   "total": "12396.076745"
# }
# }
# { "Date": 1579090945,
# {
#   "available": "401.028745",
#   "reserved": "12001.048",
#   "reserved_subtotals": {
#     "claims": "684.948",
#     "supports": "4618.0",
#     "tips": "6698.1"
#   },
#   "total": "12402.076745"
# }
# }
# { "Date": 1579126364,
# Could not connect to daemon. Are you sure it's running?
# }
# { "Date": 1579127324,
# {
#   "available": "401.028745",
#   "reserved": "12004.048",
#   "reserved_subtotals": {
#     "claims": "684.948",
#     "supports": "4618.0",
#     "tips": "6701.1"
#   },
#   "total": "12405.076745"
# }
# }
# { "Date": 1579149727,
# {
#   "available": "390.980638",
#   "reserved": "12025.058",
#   "reserved_subtotals": {
#     "claims": "694.958",
#     "supports": "4618.0",
#     "tips": "6712.1"
#   },
#   "total": "12416.038638"
# }
# }
# { "Date": 1579240346,
# {
#   "available": "291.8390555",
#   "reserved": "12196.158",
#   "reserved_subtotals": {
#     "claims": "695.058",
#     "supports": "4718.0",
#     "tips": "6783.1"
#   },
#   "total": "12487.9970555"
# }
# }
# { "Date": 1579263489,
# {
#   "available": "292.4795425",
#   "reserved": "12210.408",
#   "reserved_subtotals": {
#     "claims": "695.308",
#     "supports": "4718.0",
#     "tips": "6797.1"
#   },
#   "total": "12502.8875425"
# }
# }
# { "Date": 1579301185,
# {
#   "available": "287.479017",
#   "reserved": "12229.408",
#   "reserved_subtotals": {
#     "claims": "695.308",
#     "supports": "4723.0",
#     "tips": "6811.1"
#   },
#   "total": "12516.887017"
# }
# }
# { "Date": 1579350678,
# {
#   "available": "86.467588",
#   "reserved": "12492.258",
#   "reserved_subtotals": {
#     "claims": "900.158",
#     "supports": "4723.0",
#     "tips": "6869.1"
#   },
#   "total": "12578.725588"
# }
# }
# { "Date": 1579362698,
# {
#   "available": "76.399481",
#   "reserved": "12567.258",
#   "reserved_subtotals": {
#     "claims": "910.158",
#     "supports": "4723.0",
#     "tips": "6934.1"
#   },
#   "total": "12643.657481"
# }
# }
# { "Date": 1579389571,
# {
#   "available": "76.399481",
#   "reserved": "12623.268",
#   "reserved_subtotals": {
#     "claims": "910.158",
#     "supports": "4723.0",
#     "tips": "6990.11"
#   },
#   "total": "12699.667481"
# }
# }
# { "Date": 1579420884,
# {
#   "available": "1.398262",
#   "reserved": "12729.268",
#   "reserved_subtotals": {
#     "claims": "910.158",
#     "supports": "4798.0",
#     "tips": "7021.11"
#   },
#   "total": "12730.666262"
# }
# }
# { "Date": 1579436144,
# {
#   "available": "1.398262",
#   "reserved": "12770.268",
#   "reserved_subtotals": {
#     "claims": "910.158",
#     "supports": "4798.0",
#     "tips": "7062.11"
#   },
#   "total": "12771.666262"
# }
# }
# { "Date": 1579473795,
# {
#   "available": "1.398262",
#   "reserved": "13083.268",
#   "reserved_subtotals": {
#     "claims": "910.158",
#     "supports": "4798.0",
#     "tips": "7375.11"
#   },
#   "total": "13084.666262"
# }
# }
# { "Date": 1579500141,
# {
#   "available": "2.398262",
#   "reserved": "13089.268",
#   "reserved_subtotals": {
#     "claims": "910.158",
#     "supports": "4798.0",
#     "tips": "7381.11"
#   },
#   "total": "13091.666262"
# }
# }
# { "Date": 1579518258,
# {
#   "available": "12.396971",
#   "reserved": "13093.268",
#   "reserved_subtotals": {
#     "claims": "910.158",
#     "supports": "5098.0",
#     "tips": "7085.11"
#   },
#   "total": "13105.664971"
# }
# }
# { "Date": 1579532020,
# {
#   "available": "12.396971",
#   "reserved": "13113.268",
#   "reserved_subtotals": {
#     "claims": "910.158",
#     "supports": "5098.0",
#     "tips": "7105.11"
#   },
#   "total": "13125.664971"
# }
# }
# { "Date": 1579556024,
# {
#   "available": "12.396971",
#   "reserved": "13132.268",
#   "reserved_subtotals": {
#     "claims": "910.158",
#     "supports": "5098.0",
#     "tips": "7124.11"
#   },
#   "total": "13144.664971"
# }
# }
# { "Date": 1579562048,
# {
#   "available": "14.396971",
#   "reserved": "14132.268",
#   "reserved_subtotals": {
#     "claims": "910.158",
#     "supports": "5098.0",
#     "tips": "8124.11"
#   },
#   "total": "14146.664971"
# }
# }
# { "Date": 1579567182,
# {
#   "available": "107.396971",
#   "reserved": "14134.268",
#   "reserved_subtotals": {
#     "claims": "910.158",
#     "supports": "5098.0",
#     "tips": "8126.11"
#   },
#   "total": "14241.664971"
# }
# }
# { "Date": 1579569873,
# {
#   "available": "0.3966575",
#   "reserved": "14243.268",
#   "reserved_subtotals": {
#     "claims": "910.158",
#     "supports": "5205.0",
#     "tips": "8128.11"
#   },
#   "total": "14243.6646575"
# }
# }
# { "Date": 1579587745,
# {
#   "available": "0.3966575",
#   "reserved": "14255.268",
#   "reserved_subtotals": {
#     "claims": "910.158",
#     "supports": "5205.0",
#     "tips": "8140.11"
#   },
#   "total": "14255.6646575"
# }
# }
# { "Date": 1579618503,
# {
#   "available": "4.395654",
#   "reserved": "14298.268",
#   "reserved_subtotals": {
#     "claims": "910.158",
#     "supports": "6205.0",
#     "tips": "7183.11"
#   },
#   "total": "14302.663654"
# }
# }
# { "Date": 1579641595,
# {
#   "available": "4.395654",
#   "reserved": "14303.268",
#   "reserved_subtotals": {
#     "claims": "910.158",
#     "supports": "6205.0",
#     "tips": "7188.11"
#   },
#   "total": "14307.663654"
# }
# }
# { "Date": 1579677697,
# {
#   "available": "6.395654",
#   "reserved": "14307.268",
#   "reserved_subtotals": {
#     "claims": "910.158",
#     "supports": "6205.0",
#     "tips": "7192.11"
#   },
#   "total": "14313.663654"
# }
# }
# { "Date": 1579705730,
# {
#   "available": "6.395654",
#   "reserved": "14316.268",
#   "reserved_subtotals": {
#     "claims": "910.158",
#     "supports": "6205.0",
#     "tips": "7201.11"
#   },
#   "total": "14322.663654"
# }
# }
# { "Date": 1579706066,
# {
#   "available": "0.395341",
#   "reserved": "14322.268",
#   "reserved_subtotals": {
#     "claims": "910.158",
#     "supports": "6211.0",
#     "tips": "7201.11"
#   },
#   "total": "14322.663341"
# }
# }
# { "Date": 1579732167,
# {
#   "available": "9.395341",
#   "reserved": "14326.268",
#   "reserved_subtotals": {
#     "claims": "910.158",
#     "supports": "6211.0",
#     "tips": "7205.11"
#   },
#   "total": "14335.663341"
# }
# }
# { "Date": 1579732895,
# {
#   "available": "0.1950495",
#   "reserved": "14335.468",
#   "reserved_subtotals": {
#     "claims": "910.158",
#     "supports": "6211.0",
#     "tips": "7214.31"
#   },
#   "total": "14335.6630495"
# }
# }
# { "Date": 1579739486,
# {
#   "available": "0.1950495",
#   "reserved": "14335.468",
#   "reserved_subtotals": {
#     "claims": "910.158",
#     "supports": "6211.0",
#     "tips": "7214.31"
#   },
#   "total": "14335.6630495"
# }
# }
# { "Date": 1579760138,
# {
#   "available": "0.1950495",
#   "reserved": "14350.468",
#   "reserved_subtotals": {
#     "claims": "910.158",
#     "supports": "6211.0",
#     "tips": "7229.31"
#   },
#   "total": "14350.6630495"
# }
# }
# { "Date": 1579766872,
# {
#   "available": "0.1950495",
#   "reserved": "14355.468",
#   "reserved_subtotals": {
#     "claims": "910.158",
#     "supports": "6211.0",
#     "tips": "7234.31"
#   },
#   "total": "14355.6630495"
# }
# }
# { "Date": 1579766964,
# {
#   "available": "0.1950495",
#   "reserved": "14360.468",
#   "reserved_subtotals": {
#     "claims": "910.158",
#     "supports": "6211.0",
#     "tips": "7239.31"
#   },
#   "total": "14360.6630495"
# }
# }
# { "Date": 1579791620,
# {
#   "available": "0.1950495",
#   "reserved": "14366.468",
#   "reserved_subtotals": {
#     "claims": "910.158",
#     "supports": "6211.0",
#     "tips": "7245.31"
#   },
#   "total": "14366.6630495"
# }
# }
# { "Date": 1579844024,
# {
#   "available": "0.192827",
#   "reserved": "14400.478",
#   "reserved_subtotals": {
#     "claims": "910.168",
#     "supports": "6218.0",
#     "tips": "7272.31"
#   },
#   "total": "14400.670827"
# }
# }
# { "Date": 1579865001,
# {
#   "available": "0.192827",
#   "reserved": "14409.478",
#   "reserved_subtotals": {
#     "claims": "910.168",
#     "supports": "6218.0",
#     "tips": "7281.31"
#   },
#   "total": "14409.670827"
# }
# }
# { "Date": 1579909261,
# {
#   "available": "0.0593985",
#   "reserved": "14450.488",
#   "reserved_subtotals": {
#     "claims": "910.178",
#     "supports": "6226.0",
#     "tips": "7314.31"
#   },
#   "total": "14450.5473985"
# }
# }
# { "Date": 1579912981,
# {
#   "available": "10.0593985",
#   "reserved": "14453.488",
#   "reserved_subtotals": {
#     "claims": "910.178",
#     "supports": "6226.0",
#     "tips": "7317.31"
#   },
#   "total": "14463.5473985"
# }
# }
# { "Date": 1579916052,
# {
#   "available": "0.0590975",
#   "reserved": "14463.488",
#   "reserved_subtotals": {
#     "claims": "910.178",
#     "supports": "6236.0",
#     "tips": "7317.31"
#   },
#   "total": "14463.5470975"
# }
# }

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
f = open("/home/jack/wallet.balance").readlines()
x = []
y = []
for line in f:
    if '"supports": "' in line:
        line =line.replace('"\n', '')
        line =line.replace('"supports": "', '')
        line =line.replace('",', '')
        num = float(line)
        x.append(int(num))
        
for lines in f:
    if '"tips": "' in lines:
        lines =lines.replace('"\n', '')
        lines =lines.replace('"tips": "', '')
        lines =lines.replace('",', '')
        nums = float(lines)
        y.append(int(nums))
        
t=range(0,len(x))  
S = np.array(x)
s = np.array(y)

plt.figure(figsize=(12, 5))
#fig, ax = plt.subplots()
plt.subplot(221)
plt.grid(True)
#ax.plot(t, s, color='green')
plt.plot(t, s, color='green')
plt.xlabel('Number TIP entries', fontsize=14, color='green')
plt.subplot(222)
plt.grid(True)
#ax.plot(t, S, color='red')
plt.plot(t, S, color='red')
plt.xlabel('Number SUPPORT entries', fontsize=14, color='red')
plt.subplot(223)
plt.grid(True)
plt.plot(t, S+s, color='blue')
plt.xlabel('Number TOTAL entries', fontsize=14, color='blue')
#ax.plot(t, S+s, color='blue')
plt.subplot(224)
plt.grid(True)
plt.plot(t, s, color='green')
plt.plot(t, S+s, color='blue')
plt.plot(t, S, color='red')
plt.suptitle('Green=Tips                      Red=Support                           Blue=Total')
plt.xlabel('All three compared', fontsize=14, color='blue')

plt.subplots_adjust(top=0.92, bottom=0.01, left=0.10, right=0.95, hspace=0.55,
                    wspace=0.35)

plt.show()

# %%
f = open("/home/jack/wallet.balance").readlines()
x = []
y = []
for line in f:
    if '"supports": "' in line:
        line =line.replace('"\n', '')
        line =line.replace('"supports": "', '')
        line =line.replace('",', '')
        num = float(line)
        x.append(int(num))
        
for lines in f:
    if '"tips": "' in lines:
        lines =lines.replace('"\n', '')
        lines =lines.replace('"tips": "', '')
        lines =lines.replace('",', '')
        nums = float(lines)
        y.append(int(nums))
        
t=range(0,len(x))  
S = np.array(x)
s = np.array(y)
plt.figure(figsize=(16, 6))
#fig, ax = plt.subplots()
plt.subplot(131)
plt.grid(True)
#ax.plot(t, s, color='green')
plt.plot(t, s, color='green')
plt.xlabel('Number TIP entries', fontsize=14, color='green')
plt.subplot(132)
plt.grid(True)
#ax.plot(t, S, color='red')
plt.plot(t, S, color='red')
plt.xlabel('Number SUPPORT entries', fontsize=14, color='red')
plt.subplot(133)
plt.grid(True)
plt.plot(t, S+s, color='blue')
#ax.plot(t, S+s, color='blue')
plt.suptitle('Green=Tips                      Red=Support                           Blue=Total')
plt.xlabel('Number TOTAL of Support and Tips', fontsize=14, color='blue')
plt.ylabel='Values (LBC)'
#ax.set(xlabel='time (t)', ylabel='Values (LBC)',
#       title='Blue=Total / Green=Tips / Red=Support')
#plt.subplot(231)(t, S, color='red')
plt.show()

# %% [markdown]
# ## Notice the change in the green and the red
# Notice the change (drop) in the green (Tips) and the increase in the red (Supports) <br />
# I moved some tips to support

# %%
f = open("/home/jack/wallet.balance").readlines()
x = []
y = []
for line in f:
    if '"supports": "' in line:
        line =line.replace('"\n', '')
        line =line.replace('"supports": "', '')
        line =line.replace('",', '')
        num = float(line)
        x.append(int(num))
        
for lines in f:
    if '"tips": "' in lines:
        lines =lines.replace('"\n', '')
        lines =lines.replace('"tips": "', '')
        lines =lines.replace('",', '')
        nums = float(lines)
        y.append(int(nums))
        
t=range(0,len(x))  
S = np.array(x)
s = np.array(y)
plt.figure(figsize=(12, 8))
fig, ax = plt.subplots()
plt.subplot(131)
plt.grid(True)
#ax.plot(t, s, color='green')
plt.plot(t, s, color='green')
plt.subplot(132)
plt.grid(True)
#ax.plot(t, S, color='red')
plt.plot(t, S, color='red')
plt.subplot(133)
plt.grid(True)
plt.plot(t, S+s, color='blue')
#ax.plot(t, S+s, color='blue')
plt.suptitle('Green=Tips                      Red=Support                           Blue=Total')
ax.set(xlabel='time (t)', ylabel='Values (LBC)',
       title='Blue=Total / Green=Tips / Red=Support')
plt.show()

# %% [markdown]
# # This data is new and is being run in a cron job

# %%
# %load /home/jack/wallet2.balance
{ "Date": 1579654802,
{
  "available": "6.395654",
  "reserved": "14303.268",
  "reserved_subtotals": {
    "claims": "910.158",
    "supports": "6205.0",
    "tips": "7188.11"
  },
  "total": "14309.663654"
}
}
{ "Date": 1579658401,
{
  "available": "6.395654",
  "reserved": "14303.268",
  "reserved_subtotals": {
    "claims": "910.158",
    "supports": "6205.0",
    "tips": "7188.11"
  },
  "total": "14309.663654"
}
}
{ "Date": 1579662001,
{
  "available": "6.395654",
  "reserved": "14303.268",
  "reserved_subtotals": {
    "claims": "910.158",
    "supports": "6205.0",
    "tips": "7188.11"
  },
  "total": "14309.663654"
}
}

# %%
f = open("/home/jack/wallet2.balance").readlines()
x = []
y = []
for line in f:
    if '"supports": "' in line:
        line =line.replace('"\n', '')
        line =line.replace('"supports": "', '')
        line =line.replace('",', '')
        num = float(line)
        x.append(int(num))
        
for lines in f:
    if '"tips": "' in lines:
        lines =lines.replace('"\n', '')
        lines =lines.replace('"tips": "', '')
        lines =lines.replace('",', '')
        nums = float(lines)
        y.append(int(nums))
        
t=range(0,len(x))  
S = np.array(x)
s = np.array(y)
plt.figure(figsize=(12, 5))

plt.subplot(131)
plt.grid(True)
plt.plot(t, s, color='green')

plt.subplot(132)
plt.grid(True)
plt.plot(t, S, color='red')

plt.subplot(133)
plt.grid(True)
plt.plot(t, S+s, color='blue')

plt.suptitle('Green=Tips                      Red=Support                           Blue=Total')
ax.set(xlabel='time (t)', ylabel='Values (LBC)',
       title='Blue=Total / Green=Tips / Red=Support')
plt.show()

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
import time
DT = time.strftime("%Y%m%d%H%M")
f = open("/home/jack/wallet.balance").readlines()
x = []
for line in f:
    if '"supports": "' in line:
        line =line.replace('"\n', '')
        line =line.replace('"supports": "', '')
        line =line.replace('",', '')
        num = float(line)
        x.append(int(num))

# Data for plotting
t=range(0,len(x))
s = np.array(x)

fig, ax = plt.subplots()
ax.plot(t, s)
ax.set(xlabel='time (s)', ylabel='voltage (mV)',
       title='Total Support in LBC')
ax.grid()
filename = DT+"test.png"
print filename
fig.savefig(filename)

plt.show()
# Out:
# 202001250942test.png

# %%
# !wallet
# Out:
# {
#   "available": "703.7053835",
#   "reserved": "9564.503",
#   "reserved_subtotals": {
#     "claims": "457.503",
#     "supports": "4318.0",
#     "tips": "4789.0"
#   },
#   "total": "10268.2083835"
# }
# {
#   "available": "703.7053835",
#   "reserved": "9616.503",
#   "reserved_subtotals": {
#     "claims": "457.503",
#     "supports": "4318.0",
#     "tips": "4841.0"
#   },
#   "total": "10320.2083835"
# }
# {
#   "available": "704.7053835",
#   "reserved": "9616.503",
#   "reserved_subtotals": {
#     "claims": "457.503",
#     "supports": "4318.0",
#     "tips": "4841.0"
#   },
#   "total": "10321.2083835"
# }
# {
#   "available": "704.7053835",
#   "reserved": "9618.503",
#   "reserved_subtotals": {
#     "claims": "457.503",
#     "supports": "4318.0",
#     "tips": "4843.0"
#   },
#   "total": "10323.2083835"
# }
# {
#   "available": "724.7053835",
#   "reserved": "9618.503",
#   "reserved_subtotals": {
#     "claims": "457.503",
#     "supports": "4318.0",
#     "tips": "4843.0"
#   },
#   "total": "10343.2083835"
# }
# {
#   "available": "723.7052425",
#   "reserved": "9782.503",
#   "reserved_subtotals": {
#     "claims": "457.503",
#     "supports": "4318.0",
#     "tips": "5007.0"
#   },
#   "total": "10506.2082425"
# }
# {
#   "available": "723.7052425",
#   "reserved": "9827.503",
#   "reserved_subtotals": {
#     "claims": "457.503",
#     "supports": "4318.0",
#     "tips": "5052.0"
#   },
#   "total": "10551.2082425"
# }
# {
#   "available": "660.3136765",
#   "reserved": "9913.803",
#   "reserved_subtotals": {
#     "claims": "524.803",
#     "supports": "4318.0",
#     "tips": "5071.0"
#   },
#   "total": "10574.1166765"
# }
# {
#   "available": "650.135424",
#   "reserved": "10002.953",
#   "reserved_subtotals": {
#     "claims": "524.953",
#     "supports": "4318.0",
#     "tips": "5160.0"
#   },
#   "total": "10653.088424"
# }
# {
#   "available": "746.135424",
#   "reserved": "10978.953",
#   "reserved_subtotals": {
#     "claims": "524.953",
#     "supports": "4318.0",
#     "tips": "6136.0"
#   },
#   "total": "11725.088424"
# }
# {
#   "available": "446.133797",
#   "reserved": "11278.953",
#   "reserved_subtotals": {
#     "claims": "524.953",
#     "supports": "4618.0",
#     "tips": "6136.0"
#   },
#   "total": "11725.086797"
# }
# {
#   "available": "636.0170835",
#   "reserved": "11360.953",
#   "reserved_subtotals": {
#     "claims": "534.953",
#     "supports": "4618.0",
#     "tips": "6208.0"
#   },
#   "total": "11996.9700835"
# }
# {
#   "available": "528.02055",
#   "reserved": "11534.948",
#   "reserved_subtotals": {
#     "claims": "634.948",
#     "supports": "4618.0",
#     "tips": "6282.0"
#   },
#   "total": "12062.96855"
# }
# {
#   "available": "528.02055",
#   "reserved": "11566.948",
#   "reserved_subtotals": {
#     "claims": "634.948",
#     "supports": "4618.0",
#     "tips": "6314.0"
#   },
#   "total": "12094.96855"
# }
# {
#   "available": "528.02055",
#   "reserved": "11629.048",
#   "reserved_subtotals": {
#     "claims": "634.948",
#     "supports": "4618.0",
#     "tips": "6376.1"
#   },
#   "total": "12157.06855"
# }
# {
#   "available": "438.020394",
#   "reserved": "11835.058",
#   "reserved_subtotals": {
#     "claims": "634.958",
#     "supports": "4618.0",
#     "tips": "6582.1"
#   },
#   "total": "12273.078394"
# }
# {
#   "available": "428.0202515",
#   "reserved": "11892.058",
#   "reserved_subtotals": {
#     "claims": "634.958",
#     "supports": "4618.0",
#     "tips": "6639.1"
#   },
#   "total": "12320.0782515"
# }
# {
#   "available": "428.0202515",
#   "reserved": "11910.058",
#   "reserved_subtotals": {
#     "claims": "634.958",
#     "supports": "4618.0",
#     "tips": "6657.1"
#   },
#   "total": "12338.0782515"
# }
# { "Date": 1578967168,
# {
#   "available": "428.0202515",
#   "reserved": "11910.058",
#   "reserved_subtotals": {
#     "claims": "634.958",
#     "supports": "4618.0",
#     "tips": "6657.1"
#   },
#   "total": "12338.0782515"
# }
# }
# { "Date": 1579001785,
# {
#   "available": "380.028745",
#   "reserved": "11966.048",
#   "reserved_subtotals": {
#     "claims": "684.948",
#     "supports": "4618.0",
#     "tips": "6663.1"
#   },
#   "total": "12346.076745"
# }
# }
# { "Date": 1579003168,
# {
#   "available": "380.028745",
#   "reserved": "11966.048",
#   "reserved_subtotals": {
#     "claims": "684.948",
#     "supports": "4618.0",
#     "tips": "6663.1"
#   },
#   "total": "12346.076745"
# }
# }
# { "Date": 1579041407,
# {
#   "available": "380.028745",
#   "reserved": "11981.048",
#   "reserved_subtotals": {
#     "claims": "684.948",
#     "supports": "4618.0",
#     "tips": "6678.1"
#   },
#   "total": "12361.076745"
# }
# }
# { "Date": 1579082336,
# {
#   "available": "401.028745",
#   "reserved": "11995.048",
#   "reserved_subtotals": {
#     "claims": "684.948",
#     "supports": "4618.0",
#     "tips": "6692.1"
#   },
#   "total": "12396.076745"
# }
# }
# { "Date": 1579090945,
# {
#   "available": "401.028745",
#   "reserved": "12001.048",
#   "reserved_subtotals": {
#     "claims": "684.948",
#     "supports": "4618.0",
#     "tips": "6698.1"
#   },
#   "total": "12402.076745"
# }
# }
# { "Date": 1579126364,
# Could not connect to daemon. Are you sure it's running?
# }
# { "Date": 1579127324,
# {
#   "available": "401.028745",
#   "reserved": "12004.048",
#   "reserved_subtotals": {
#     "claims": "684.948",
#     "supports": "4618.0",
#     "tips": "6701.1"
#   },
#   "total": "12405.076745"
# }
# }
# { "Date": 1579149727,
# {
#   "available": "390.980638",
#   "reserved": "12025.058",
#   "reserved_subtotals": {
#     "claims": "694.958",
#     "supports": "4618.0",
#     "tips": "6712.1"
#   },
#   "total": "12416.038638"
# }
# }
# { "Date": 1579240346,
# {
#   "available": "291.8390555",
#   "reserved": "12196.158",
#   "reserved_subtotals": {
#     "claims": "695.058",
#     "supports": "4718.0",
#     "tips": "6783.1"
#   },
#   "total": "12487.9970555"
# }
# }
# { "Date": 1579263489,
# {
#   "available": "292.4795425",
#   "reserved": "12210.408",
#   "reserved_subtotals": {
#     "claims": "695.308",
#     "supports": "4718.0",
#     "tips": "6797.1"
#   },
#   "total": "12502.8875425"
# }
# }
# { "Date": 1579301185,
# {
#   "available": "287.479017",
#   "reserved": "12229.408",
#   "reserved_subtotals": {
#     "claims": "695.308",
#     "supports": "4723.0",
#     "tips": "6811.1"
#   },
#   "total": "12516.887017"
# }
# }
# { "Date": 1579350678,
# {
#   "available": "86.467588",
#   "reserved": "12492.258",
#   "reserved_subtotals": {
#     "claims": "900.158",
#     "supports": "4723.0",
#     "tips": "6869.1"
#   },
#   "total": "12578.725588"
# }
# }
# { "Date": 1579362698,
# {
#   "available": "76.399481",
#   "reserved": "12567.258",
#   "reserved_subtotals": {
#     "claims": "910.158",
#     "supports": "4723.0",
#     "tips": "6934.1"
#   },
#   "total": "12643.657481"
# }
# }
# { "Date": 1579389571,
# {
#   "available": "76.399481",
#   "reserved": "12623.268",
#   "reserved_subtotals": {
#     "claims": "910.158",
#     "supports": "4723.0",
#     "tips": "6990.11"
#   },
#   "total": "12699.667481"
# }
# }
# { "Date": 1579420884,
# {
#   "available": "1.398262",
#   "reserved": "12729.268",
#   "reserved_subtotals": {
#     "claims": "910.158",
#     "supports": "4798.0",
#     "tips": "7021.11"
#   },
#   "total": "12730.666262"
# }
# }
# { "Date": 1579436144,
# {
#   "available": "1.398262",
#   "reserved": "12770.268",
#   "reserved_subtotals": {
#     "claims": "910.158",
#     "supports": "4798.0",
#     "tips": "7062.11"
#   },
#   "total": "12771.666262"
# }
# }
# { "Date": 1579473795,
# {
#   "available": "1.398262",
#   "reserved": "13083.268",
#   "reserved_subtotals": {
#     "claims": "910.158",
#     "supports": "4798.0",
#     "tips": "7375.11"
#   },
#   "total": "13084.666262"
# }
# }
# { "Date": 1579500141,
# {
#   "available": "2.398262",
#   "reserved": "13089.268",
#   "reserved_subtotals": {
#     "claims": "910.158",
#     "supports": "4798.0",
#     "tips": "7381.11"
#   },
#   "total": "13091.666262"
# }
# }
# { "Date": 1579518258,
# {
#   "available": "12.396971",
#   "reserved": "13093.268",
#   "reserved_subtotals": {
#     "claims": "910.158",
#     "supports": "5098.0",
#     "tips": "7085.11"
#   },
#   "total": "13105.664971"
# }
# }
# { "Date": 1579532020,
# {
#   "available": "12.396971",
#   "reserved": "13113.268",
#   "reserved_subtotals": {
#     "claims": "910.158",
#     "supports": "5098.0",
#     "tips": "7105.11"
#   },
#   "total": "13125.664971"
# }
# }
# { "Date": 1579556024,
# {
#   "available": "12.396971",
#   "reserved": "13132.268",
#   "reserved_subtotals": {
#     "claims": "910.158",
#     "supports": "5098.0",
#     "tips": "7124.11"
#   },
#   "total": "13144.664971"
# }
# }
# { "Date": 1579562048,
# {
#   "available": "14.396971",
#   "reserved": "14132.268",
#   "reserved_subtotals": {
#     "claims": "910.158",
#     "supports": "5098.0",
#     "tips": "8124.11"
#   },
#   "total": "14146.664971"
# }
# }
# { "Date": 1579567182,
# {
#   "available": "107.396971",
#   "reserved": "14134.268",
#   "reserved_subtotals": {
#     "claims": "910.158",
#     "supports": "5098.0",
#     "tips": "8126.11"
#   },
#   "total": "14241.664971"
# }
# }
# { "Date": 1579569873,
# {
#   "available": "0.3966575",
#   "reserved": "14243.268",
#   "reserved_subtotals": {
#     "claims": "910.158",
#     "supports": "5205.0",
#     "tips": "8128.11"
#   },
#   "total": "14243.6646575"
# }
# }
# { "Date": 1579587745,
# {
#   "available": "0.3966575",
#   "reserved": "14255.268",
#   "reserved_subtotals": {
#     "claims": "910.158",
#     "supports": "5205.0",
#     "tips": "8140.11"
#   },
#   "total": "14255.6646575"
# }
# }
# { "Date": 1579618503,
# {
#   "available": "4.395654",
#   "reserved": "14298.268",
#   "reserved_subtotals": {
#     "claims": "910.158",
#     "supports": "6205.0",
#     "tips": "7183.11"
#   },
#   "total": "14302.663654"
# }
# }
# { "Date": 1579641595,
# {
#   "available": "4.395654",
#   "reserved": "14303.268",
#   "reserved_subtotals": {
#     "claims": "910.158",
#     "supports": "6205.0",
#     "tips": "7188.11"
#   },
#   "total": "14307.663654"
# }
# }
# { "Date": 1579677697,
# {
#   "available": "6.395654",
#   "reserved": "14307.268",
#   "reserved_subtotals": {
#     "claims": "910.158",
#     "supports": "6205.0",
#     "tips": "7192.11"
#   },
#   "total": "14313.663654"
# }
# }
# { "Date": 1579705730,
# {
#   "available": "6.395654",
#   "reserved": "14316.268",
#   "reserved_subtotals": {
#     "claims": "910.158",
#     "supports": "6205.0",
#     "tips": "7201.11"
#   },
#   "total": "14322.663654"
# }
# }
# { "Date": 1579706066,
# {
#   "available": "0.395341",
#   "reserved": "14322.268",
#   "reserved_subtotals": {
#     "claims": "910.158",
#     "supports": "6211.0",
#     "tips": "7201.11"
#   },
#   "total": "14322.663341"
# }
# }
# { "Date": 1579732167,
# {
#   "available": "9.395341",
#   "reserved": "14326.268",
#   "reserved_subtotals": {
#     "claims": "910.158",
#     "supports": "6211.0",
#     "tips": "7205.11"
#   },
#   "total": "14335.663341"
# }
# }
# { "Date": 1579732895,
# {
#   "available": "0.1950495",
#   "reserved": "14335.468",
#   "reserved_subtotals": {
#     "claims": "910.158",
#     "supports": "6211.0",
#     "tips": "7214.31"
#   },
#   "total": "14335.6630495"
# }
# }
# { "Date": 1579739486,
# {
#   "available": "0.1950495",
#   "reserved": "14335.468",
#   "reserved_subtotals": {
#     "claims": "910.158",
#     "supports": "6211.0",
#     "tips": "7214.31"
#   },
#   "total": "14335.6630495"
# }
# }
# { "Date": 1579760138,
# {
#   "available": "0.1950495",
#   "reserved": "14350.468",
#   "reserved_subtotals": {
#     "claims": "910.158",
#     "supports": "6211.0",
#     "tips": "7229.31"
#   },
#   "total": "14350.6630495"
# }
# }
# { "Date": 1579766872,
# {
#   "available": "0.1950495",
#   "reserved": "14355.468",
#   "reserved_subtotals": {
#     "claims": "910.158",
#     "supports": "6211.0",
#     "tips": "7234.31"
#   },
#   "total": "14355.6630495"
# }
# }
# { "Date": 1579766964,
# {
#   "available": "0.1950495",
#   "reserved": "14360.468",
#   "reserved_subtotals": {
#     "claims": "910.158",
#     "supports": "6211.0",
#     "tips": "7239.31"
#   },
#   "total": "14360.6630495"
# }
# }
# { "Date": 1579791620,
# {
#   "available": "0.1950495",
#   "reserved": "14366.468",
#   "reserved_subtotals": {
#     "claims": "910.158",
#     "supports": "6211.0",
#     "tips": "7245.31"
#   },
#   "total": "14366.6630495"
# }
# }
# { "Date": 1579844024,
# {
#   "available": "0.192827",
#   "reserved": "14400.478",
#   "reserved_subtotals": {
#     "claims": "910.168",
#     "supports": "6218.0",
#     "tips": "7272.31"
#   },
#   "total": "14400.670827"
# }
# }
# { "Date": 1579865001,
# {
#   "available": "0.192827",
#   "reserved": "14409.478",
#   "reserved_subtotals": {
#     "claims": "910.168",
#     "supports": "6218.0",
#     "tips": "7281.31"
#   },
#   "total": "14409.670827"
# }
# }

# %%
import time
DT = time.strftime("%Y-%m-%d-%H:%M")
print DT
# Out:
# 2020-01-24-19:28

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import time
# %matplotlib inline
import matplotlib.patches as mpatches
DT = time.strftime("%Y-%m-%d-%H:%M")
# use for filename
dt = time.strftime("%Y%m%d%H%M-")
f = open("/home/jack/wallet.balance").readlines()
x = []
y = []
for line in f:
    if '"supports": "' in line:
        line =line.replace('"\n', '')
        line =line.replace('"supports": "', '')
        line =line.replace('",', '')
        num = float(line)
        x.append(int(num))

for lines in f:
    if '"tips": "' in lines:
        lines =lines.replace('"\n', '')
        lines =lines.replace('"tips": "', '')
        lines =lines.replace('",', '')
        nums = float(lines)
        y.append(int(nums))        
        
# Data for plotting
t=range(0,len(x))  
S = np.array(x)
s = np.array(y)

fig, ax = plt.subplots(dpi=150)
ax.grid(color = "salmon", alpha = .9, linewidth = 2)

red_patch = mpatches.Patch(color='green', alpha = .5, label='Supports')
blue_patch = mpatches.Patch(color='blue', alpha = .5, label='Tips')
plt.legend(handles=[red_patch, blue_patch])
ax.set(xlabel='DATE: '+DT)
'''
ax.set(xlabel='DATE: '+DT+'  Samples(Scale = '+NumOfSamples+' samples)   Dropout '+ Dropout, ylabel='Last Training Loss: '+Trainingloss,
       title='Plot Losses from Last '+NumOfSamples+' Samples.   Epoch: '+Epoch+' \n Last: EvaluationLoss: \
'+Evaluationloss+"    LearningRate: "+LearningRate )
'''
print "Green = Supports"
print "Blue = Tips"
fig.patch.set_facecolor('salmon')
#plt.plot(yinc, y, color= 'green', alpha = .5)
#plt.plot(yinc, y, color= 'red', alpha = .5)
plt.plot(t, s, color= 'blue')
plt.plot(t, S, color= 'green')
filename = dt+"test1.png"
filename0 = dt+"full.png"
print filename," ",filename0
fig.savefig(filename)
plt.savefig(filename0 , bbox_inches="tight", facecolor="salmon")

plt.show()
# Out:
# Green = Supports
# Blue = Tips
# 202001250946-test1.png   202001250946-full.png

# %%
from PIL import Image
IMG = Image.open('202001250946-test1.png')
IMG
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=900x600 at 0x7F85A65AD9D0>

# %%
from PIL import Image
IMG = Image.open('202001250946-full.png')
print IMG.size
IMG
# Out:
# (798, 549)
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=798x549 at 0x7F85A6B09C50>

# %% [markdown]
# ## Very little data history > wallet2.balance

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import time
# %matplotlib inline
import matplotlib.patches as mpatches
DT = time.strftime("%Y-%m-%d:%H")
dt = time.strftime("%Y%m%d%H%M-")
f = open("/home/jack/wallet2.balance").readlines()
x = []
y = []
for line in f:
    if '"supports": "' in line:
        line =line.replace('"\n', '')
        line =line.replace('"supports": "', '')
        line =line.replace('",', '')
        num = float(line)
        x.append(int(num))

for lines in f:
    if '"tips": "' in lines:
        lines =lines.replace('"\n', '')
        lines =lines.replace('"tips": "', '')
        lines =lines.replace('",', '')
        nums = float(lines)
        y.append(int(nums))        
        
# Data for plotting
t=range(0,len(x))  
S = np.array(x)
s = np.array(y)

fig, ax = plt.subplots(dpi=150)
ax.grid(color = "salmon", alpha = .9, linewidth = 2)

red_patch = mpatches.Patch(color='green', alpha = .5, label='Supports')
blue_patch = mpatches.Patch(color='blue', alpha = .5, label='Tips')
plt.legend(handles=[red_patch, blue_patch])
ax.set(xlabel='DATE: '+DT)
'''
ax.set(xlabel='DATE: '+DT+'  Samples(Scale = '+NumOfSamples+' samples)   Dropout '+ Dropout, ylabel='Last Training Loss: '+Trainingloss,
       title='Plot Losses from Last '+NumOfSamples+' Samples.   Epoch: '+Epoch+' \n Last: EvaluationLoss: \
'+Evaluationloss+"    LearningRate: "+LearningRate )
'''
print "Green = Supports"
print "Blue = Tips"
fig.patch.set_facecolor('salmon')
#plt.plot(yinc, y, color= 'green', alpha = .5)
#plt.plot(yinc, y, color= 'red', alpha = .5)
plt.plot(t, s, color= 'blue')
plt.plot(t, S, color= 'green')

#fig.savefig("test.png")
plt.savefig(dt+'wallet_crone.png', bbox_inches="tight", facecolor="salmon")

plt.show()
# Out:
# Green = Supports
# Blue = Tips
